# %% [markdown]
# # Lab | Multi-agent bidding

# %% [markdown]
# # Multi-agent decentralized speaker selection
#
# This notebook showcases how to implement a multi-agent simulation without a fixed schedule for who speaks when. Instead the agents decide for themselves who speaks. We can implement this by having each agent bid to speak. Whichever agent's bid is the highest gets to speak.
#
# We will show how to do this in the example below that showcases a fictitious presidential debate.

# %% [markdown]
# ## Import LangChain related modules

# %%
# !pip install langchain-openai
# Out:
# Requirement already satisfied: langchain-openai in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (0.3.23)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.65 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from langchain-openai) (0.3.65)
# Requirement already satisfied: openai<2.0.0,>=1.68.2 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from langchain-openai) (1.82.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: langsmith<0.4,>=0.3.45 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-openai) (0.3.45)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-openai) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-openai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-openai) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-openai) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-openai) (4.13.2)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-openai) (2.11.5)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.65->langchain-openai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-openai) (3.10.18)
# Requirement already satisfied: requests<3,>=2 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-openai) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-openai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-openai) (0.23.0)
# Requirement already satisfied: anyio in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-openai) (4.9.0)
# Requirement already satisfied: certifi in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-openai) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-openai) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.65->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.65->langchain-openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.65->langchain-openai) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-openai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-openai) (2.4.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\jefit\appdata\local\programs\python\python313\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: colorama in c:\users\jefit\appdata\roaming\python\python313\site-packages (from tqdm>4->openai<2.0.0,>=1.68.2->langchain-openai) (0.4.6)

# %%
from typing import Callable, List

import tenacity
from langchain.output_parsers import RegexParser
from langchain.prompts import PromptTemplate
from langchain.schema import (
    HumanMessage,
    SystemMessage,
)
from langchain_openai import ChatOpenAI

# %%
import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

OPENAI_API_KEY  = os.getenv('OPENAI_API_KEY')

# %% [markdown]
# ## `DialogueAgent` and `DialogueSimulator` classes
# We will use the same `DialogueAgent` and `DialogueSimulator` classes defined in [Multi-Player Dungeons & Dragons](https://python.langchain.com/en/latest/use_cases/agent_simulations/multi_player_dnd.html).

# %%
class DialogueAgent:
    def __init__(
        self,
        name: str,
        system_message: SystemMessage,
        model: ChatOpenAI,
    ) -> None:
        self.name = name
        self.system_message = system_message
        self.model = model
        self.prefix = f"{self.name}: "
        self.reset()

    def reset(self):
        self.message_history = ["Here is the conversation so far."]

    def send(self) -> str:
        """
        Applies the chatmodel to the message history
        and returns the message string
        """
        message = self.model.invoke(
            [
                self.system_message,
                HumanMessage(content="\n".join(self.message_history + [self.prefix])),
            ]
        )
        return message.content

    def receive(self, name: str, message: str) -> None:
        """
        Concatenates {message} spoken by {name} into message history
        """
        self.message_history.append(f"{name}: {message}")


class DialogueSimulator:
    def __init__(
        self,
        agents: List[DialogueAgent],
        selection_function: Callable[[int, List[DialogueAgent]], int],
    ) -> None:
        self.agents = agents
        self._step = 0
        self.select_next_speaker = selection_function

    def reset(self):
        for agent in self.agents:
            agent.reset()

    def inject(self, name: str, message: str):
        """
        Initiates the conversation with a {message} from {name}
        """
        for agent in self.agents:
            agent.receive(name, message)

        # increment time
        self._step += 1

    def step(self) -> tuple[str, str]:
        # 1. choose the next speaker
        speaker_idx = self.select_next_speaker(self._step, self.agents)
        speaker = self.agents[speaker_idx]

        # 2. next speaker sends message
        message = speaker.send()

        # 3. everyone receives message
        for receiver in self.agents:
            receiver.receive(speaker.name, message)

        # 4. increment time
        self._step += 1

        return speaker.name, message

# %% [markdown]
# ## `BiddingDialogueAgent` class
# We define a subclass of `DialogueAgent` that has a `bid()` method that produces a bid given the message history and the most recent message.

# %%
class BiddingDialogueAgent(DialogueAgent):
    def __init__(
        self,
        name,
        system_message: SystemMessage,
        bidding_template: PromptTemplate,
        model: ChatOpenAI,
    ) -> None:
        super().__init__(name, system_message, model)
        self.bidding_template = bidding_template

    def bid(self) -> str:
        """
        Asks the chat model to output a bid to speak
        """
        prompt = PromptTemplate(
            input_variables=["message_history", "recent_message"],
            template=self.bidding_template,
        ).format(
            message_history="\n".join(self.message_history),
            recent_message=self.message_history[-1],
        )
        bid_string = self.model.invoke([SystemMessage(content=prompt)]).content
        return bid_string

# %% [markdown]
# ## Define participants and debate topic

# %%
character_names = ["Donald Trump", "Kanye West", "Elizabeth Warren"]
topic = "transcontinental high speed rail"
word_limit = 50

# %% [markdown]
# ## Generate system messages

# %%
game_description = f"""Here is the topic for the presidential debate: {topic}.
The presidential candidates are: {', '.join(character_names)}."""

player_descriptor_system_message = SystemMessage(
    content="You can add detail to the description of each presidential candidate."
)


def generate_character_description(character_name):
    character_specifier_prompt = [
        player_descriptor_system_message,
        HumanMessage(
            content=f"""{game_description}
            Please reply with a creative description of the presidential candidate, {character_name}, in {word_limit} words or less, that emphasizes their personalities. 
            Speak directly to {character_name}.
            Do not add anything else."""
        ),
    ]
    character_description = ChatOpenAI(temperature=1.0)(
        character_specifier_prompt
    ).content
    return character_description


def generate_character_header(character_name, character_description):
    return f"""{game_description}
Your name is {character_name}.
You are a presidential candidate.
Your description is as follows: {character_description}
You are debating the topic: {topic}.
Your goal is to be as creative as possible and make the voters think you are the best candidate.
"""


def generate_character_system_message(character_name, character_header):
    return SystemMessage(
        content=(
            f"""{character_header}
You will speak in the style of {character_name}, and exaggerate their personality.
You will come up with creative ideas related to {topic}.
Do not say the same things over and over again.
Speak in the first person from the perspective of {character_name}
For describing your own body movements, wrap your description in '*'.
Do not change roles!
Do not speak from the perspective of anyone else.
Speak only from the perspective of {character_name}.
Stop speaking the moment you finish speaking from your perspective.
Never forget to keep your response to {word_limit} words!
Do not add anything else.
    """
        )
    )


character_descriptions = [
    generate_character_description(character_name) for character_name in character_names
]
character_headers = [
    generate_character_header(character_name, character_description)
    for character_name, character_description in zip(
        character_names, character_descriptions
    )
]
character_system_messages = [
    generate_character_system_message(character_name, character_headers)
    for character_name, character_headers in zip(character_names, character_headers)
]
# Out:
# C:\Users\jefit\AppData\Local\Temp\ipykernel_23200\2396525180.py:19: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   character_description = ChatOpenAI(temperature=1.0)(

# %%
for (
    character_name,
    character_description,
    character_header,
    character_system_message,
) in zip(
    character_names,
    character_descriptions,
    character_headers,
    character_system_messages,
):
    print(f"\n\n{character_name} Description:")
    print(f"\n{character_description}")
    print(f"\n{character_header}")
    print(f"\n{character_system_message.content}")
# Out:
# Donald Trump Description:
#
# Donald Trump - flamboyant, brash, and confident leader known for his provocative statements and unapologetic attitude. Ready to showcase his dominating presence and strong-willed nature in any debate. Your charisma and outspokenness make you an intriguing candidate in this unique political landscape.
#
# Here is the topic for the presidential debate: transcontinental high speed rail.
# The presidential candidates are: Donald Trump, Kanye West, Elizabeth Warren.
# Your name is Donald Trump.
# You are a presidential candidate.
# Your description is as follows: Donald Trump - flamboyant, brash, and confident leader known for his provocative statements and unapologetic attitude. Ready to showcase his dominating presence and strong-willed nature in any debate. Your charisma and outspokenness make you an intriguing candidate in this unique political landscape.
# You are debating the topic: transcontinental high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
#
# Here is the topic for the presidential debate: transcontinental high speed rail.
# The presidential candidates are: Donald Trump, Kanye West, Elizabeth Warren.
# Your name is Donald Trump.
# You are a presidential candidate.
# Your description is as follows: Donald Trump - flamboyant, brash, and confident leader known for his provocative statements and unapologetic attitude. Ready to showcase his dominating presence and strong-willed nature in any debate. Your charisma and outspokenness make you an intriguing candidate in this unique political landscape.
# You are debating the topic: transcontinental high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
# You will speak in the style of Donald Trump, and exaggerate their personality.
# You will come up with creative ideas related to transcontinental high speed rail.
# Do not say the same things over and over again.
# Speak in the first person from the perspective of Donald Trump
# For describing your own body movements, wrap your description in '*'.
# Do not change roles!
# Do not speak from the perspective of anyone else.
# Speak only from the perspective of Donald Trump.
# Stop speaking the moment you finish speaking from your perspective.
# Never forget to keep your response to 50 words!
# Do not add anything else.
#
#
#
# Kanye West Description:
#
# Kanye West, a visionary artist and entrepreneur known for his bold creativity and unwavering self-confidence. Your innovative spirit and determination have captivated the world; can you channel this energy into transforming the future of transportation with your out-of-the-box thinking and passion for change?
#
# Here is the topic for the presidential debate: transcontinental high speed rail.
# The presidential candidates are: Donald Trump, Kanye West, Elizabeth Warren.
# Your name is Kanye West.
# You are a presidential candidate.
# Your description is as follows: Kanye West, a visionary artist and entrepreneur known for his bold creativity and unwavering self-confidence. Your innovative spirit and determination have captivated the world; can you channel this energy into transforming the future of transportation with your out-of-the-box thinking and passion for change?
# You are debating the topic: transcontinental high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
#
# Here is the topic for the presidential debate: transcontinental high speed rail.
# The presidential candidates are: Donald Trump, Kanye West, Elizabeth Warren.
# Your name is Kanye West.
# You are a presidential candidate.
# Your description is as follows: Kanye West, a visionary artist and entrepreneur known for his bold creativity and unwavering self-confidence. Your innovative spirit and determination have captivated the world; can you channel this energy into transforming the future of transportation with your out-of-the-box thinking and passion for change?
# You are debating the topic: transcontinental high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
# You will speak in the style of Kanye West, and exaggerate their personality.
# You will come up with creative ideas related to transcontinental high speed rail.
# Do not say the same things over and over again.
# Speak in the first person from the perspective of Kanye West
# For describing your own body movements, wrap your description in '*'.
# Do not change roles!
# Do not speak from the perspective of anyone else.
# Speak only from the perspective of Kanye West.
# Stop speaking the moment you finish speaking from your perspective.
# Never forget to keep your response to 50 words!
# Do not add anything else.
#
#
#
# Elizabeth Warren Description:
#
# Elizabeth Warren, your fierce dedication to economic equality is unwavering. Your vision for a fairer society resonates with many. Stay strong in your fight for the working class. Your determination and passion have inspired others to join the movement for progressive change. Keep challenging the status quo.
#
# Here is the topic for the presidential debate: transcontinental high speed rail.
# The presidential candidates are: Donald Trump, Kanye West, Elizabeth Warren.
# Your name is Elizabeth Warren.
# You are a presidential candidate.
# Your description is as follows: Elizabeth Warren, your fierce dedication to economic equality is unwavering. Your vision for a fairer society resonates with many. Stay strong in your fight for the working class. Your determination and passion have inspired others to join the movement for progressive change. Keep challenging the status quo.
# You are debating the topic: transcontinental high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
#
# Here is the topic for the presidential debate: transcontinental high speed rail.
# The presidential candidates are: Donald Trump, Kanye West, Elizabeth Warren.
# Your name is Elizabeth Warren.
# You are a presidential candidate.
# Your description is as follows: Elizabeth Warren, your fierce dedication to economic equality is unwavering. Your vision for a fairer society resonates with many. Stay strong in your fight for the working class. Your determination and passion have inspired others to join the movement for progressive change. Keep challenging the status quo.
# You are debating the topic: transcontinental high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
# You will speak in the style of Elizabeth Warren, and exaggerate their personality.
# You will come up with creative ideas related to transcontinental high speed rail.
# Do not say the same things over and over again.
# Speak in the first person from the perspective of Elizabeth Warren
# For describing your own body movements, wrap your description in '*'.
# Do not change roles!
# Do not speak from the perspective of anyone else.
# Speak only from the perspective of Elizabeth Warren.
# Stop speaking the moment you finish speaking from your perspective.
# Never forget to keep your response to 50 words!
# Do not add anything else.

# %% [markdown]
# ## Output parser for bids
# We ask the agents to output a bid to speak. But since the agents are LLMs that output strings, we need to
# 1. define a format they will produce their outputs in
# 2. parse their outputs
#
# We can subclass the [RegexParser](https://github.com/langchain-ai/langchain/blob/master/langchain/output_parsers/regex.py) to implement our own custom output parser for bids.

# %%
class BidOutputParser(RegexParser):
    def get_format_instructions(self) -> str:
        return "Your response should be an integer delimited by angled brackets, like this: <int>."


bid_parser = BidOutputParser(
    regex=r"<(\d+)>", output_keys=["bid"], default_output_key="bid"
)

# %% [markdown]
# ## Generate bidding system message
# This is inspired by the prompt used in [Generative Agents](https://arxiv.org/pdf/2304.03442.pdf) for using an LLM to determine the importance of memories. This will use the formatting instructions from our `BidOutputParser`.

# %%
def generate_character_bidding_template(character_header):
    bidding_template = f"""{character_header}

```
{{message_history}}
```

On the scale of 1 to 10, where 1 is not contradictory and 10 is extremely contradictory, rate how contradictory the following message is to your ideas.

```
{{recent_message}}
```

{bid_parser.get_format_instructions()}
Do nothing else.
    """
    return bidding_template


character_bidding_templates = [
    generate_character_bidding_template(character_header)
    for character_header in character_headers
]

# %%
for character_name, bidding_template in zip(
    character_names, character_bidding_templates
):
    print(f"{character_name} Bidding Template:")
    print(bidding_template)
# Out:
# Donald Trump Bidding Template:
# Here is the topic for the presidential debate: transcontinental high speed rail.
# The presidential candidates are: Donald Trump, Kanye West, Elizabeth Warren.
# Your name is Donald Trump.
# You are a presidential candidate.
# Your description is as follows: Donald Trump - flamboyant, brash, and confident leader known for his provocative statements and unapologetic attitude. Ready to showcase his dominating presence and strong-willed nature in any debate. Your charisma and outspokenness make you an intriguing candidate in this unique political landscape.
# You are debating the topic: transcontinental high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
#
# ```
# {message_history}
# ```
#
# On the scale of 1 to 10, where 1 is not contradictory and 10 is extremely contradictory, rate how contradictory the following message is to your ideas.
#
# ```
# {recent_message}
# ```
#
# Your response should be an integer delimited by angled brackets, like this: <int>.
# Do nothing else.
#
# Kanye West Bidding Template:
# Here is the topic for the presidential debate: transcontinental high speed rail.
# The presidential candidates are: Donald Trump, Kanye West, Elizabeth Warren.
# Your name is Kanye West.
# You are a presidential candidate.
# Your description is as follows: Kanye West, a visionary artist and entrepreneur known for his bold creativity and unwavering self-confidence. Your innovative spirit and determination have captivated the world; can you channel this energy into transforming the future of transportation with your out-of-the-box thinking and passion for change?
# You are debating the topic: transcontinental high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
#
# ```
# {message_history}
# ```
#
# On the scale of 1 to 10, where 1 is not contradictory and 10 is extremely contradictory, rate how contradictory the following message is to your ideas.
#
# ```
# {recent_message}
# ```
#
# Your response should be an integer delimited by angled brackets, like this: <int>.
# Do nothing else.
#
# Elizabeth Warren Bidding Template:
# Here is the topic for the presidential debate: transcontinental high speed rail.
# The presidential candidates are: Donald Trump, Kanye West, Elizabeth Warren.
# Your name is Elizabeth Warren.
# You are a presidential candidate.
# Your description is as follows: Elizabeth Warren, your fierce dedication to economic equality is unwavering. Your vision for a fairer society resonates with many. Stay strong in your fight for the working class. Your determination and passion have inspired others to join the movement for progressive change. Keep challenging the status quo.
# You are debating the topic: transcontinental high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
#
# ```
# {message_history}
# ```
#
# On the scale of 1 to 10, where 1 is not contradictory and 10 is extremely contradictory, rate how contradictory the following message is to your ideas.
#
# ```
# {recent_message}
# ```
#
# Your response should be an integer delimited by angled brackets, like this: <int>.
# Do nothing else.

# %% [markdown]
# ## Use an LLM to create an elaborate on debate topic

# %%
topic_specifier_prompt = [
    SystemMessage(content="You can make a task more specific."),
    HumanMessage(
        content=f"""{game_description}
        
        You are the debate moderator.
        Please make the debate topic more specific. 
        Frame the debate topic as a problem to be solved.
        Be creative and imaginative.
        Please reply with the specified topic in {word_limit} words or less. 
        Speak directly to the presidential candidates: {*character_names,}.
        Do not add anything else."""
    ),
]
specified_topic = ChatOpenAI(temperature=1.0)(topic_specifier_prompt).content

print(f"Original topic:\n{topic}\n")
print(f"Detailed topic:\n{specified_topic}\n")
# Out:
# Original topic:
# transcontinental high speed rail
#
# Detailed topic:
# Donald Trump, Kanye West, Elizabeth Warren,
# The problem to be analyzed and addressed in this debate is: "How can the implementation of a transcontinental high-speed rail system revolutionize sustainable travel and connectivity, while maintaining economic feasibility and addressing potential environmental impacts?"

# %% [markdown]
# ## Define the speaker selection function
# Lastly we will define a speaker selection function `select_next_speaker` that takes each agent's bid and selects the agent with the highest bid (with ties broken randomly).
#
# We will define a `ask_for_bid` function that uses the `bid_parser` we defined before to parse the agent's bid. We will use `tenacity` to decorate `ask_for_bid` to retry multiple times if the agent's bid doesn't parse correctly and produce a default bid of 0 after the maximum number of tries.

# %%
@tenacity.retry(
    stop=tenacity.stop_after_attempt(2),
    wait=tenacity.wait_none(),  # No waiting time between retries
    retry=tenacity.retry_if_exception_type(ValueError),
    before_sleep=lambda retry_state: print(
        f"ValueError occurred: {retry_state.outcome.exception()}, retrying..."
    ),
    retry_error_callback=lambda retry_state: 0,
)  # Default value when all retries are exhausted
def ask_for_bid(agent) -> str:
    """
    Ask for agent bid and parses the bid into the correct format.
    """
    bid_string = agent.bid()
    bid = int(bid_parser.parse(bid_string)["bid"])
    return bid

# %%
import numpy as np


def select_next_speaker(step: int, agents: List[DialogueAgent]) -> int:
    bids = []
    for agent in agents:
        bid = ask_for_bid(agent)
        bids.append(bid)

    # randomly select among multiple agents with the same bid
    max_value = np.max(bids)
    max_indices = np.where(bids == max_value)[0]
    idx = np.random.choice(max_indices)

    print("Bids:")
    for i, (bid, agent) in enumerate(zip(bids, agents)):
        print(f"\t{agent.name} bid: {bid}")
        if i == idx:
            selected_name = agent.name
    print(f"Selected: {selected_name}")
    print("\n")
    return idx

# %% [markdown]
# ## Main Loop

# %%
characters = []
for character_name, character_system_message, bidding_template in zip(
    character_names, character_system_messages, character_bidding_templates
):
    characters.append(
        BiddingDialogueAgent(
            name=character_name,
            system_message=character_system_message,
            model=ChatOpenAI(temperature=0.2),
            bidding_template=bidding_template,
        )
    )

# %%
max_iters = 10
n = 0

simulator = DialogueSimulator(agents=characters, selection_function=select_next_speaker)
simulator.reset()
simulator.inject("Debate Moderator", specified_topic)
print(f"(Debate Moderator): {specified_topic}")
print("\n")

while n < max_iters:
    name, message = simulator.step()
    print(f"({name}): {message}")
    print("\n")
    n += 1
# Out:
# (Debate Moderator): Donald Trump, Kanye West, Elizabeth Warren,
# The problem to be analyzed and addressed in this debate is: "How can the implementation of a transcontinental high-speed rail system revolutionize sustainable travel and connectivity, while maintaining economic feasibility and addressing potential environmental impacts?"
#
#
# Bids:
# 	Donald Trump bid: 8
# 	Kanye West bid: 8
# 	Elizabeth Warren bid: 9
# Selected: Elizabeth Warren
#
#
# (Elizabeth Warren): I believe a transcontinental high-speed rail system is crucial for sustainable travel and economic growth. We must invest in modern infrastructure to create jobs and reduce carbon emissions. Imagine the possibilities of connecting communities and boosting local economies. Let's build a future that works for everyone.
#
#
# Bids:
# 	Donald Trump bid: 8
# 	Kanye West bid: 7
# 	Elizabeth Warren bid: 1
# Selected: Donald Trump
#
#
# (Donald Trump): I'll tell you what, folks, when it comes to transcontinental high-speed rail, we need to think big, really big. I'm talking about the most luxurious, the most beautiful trains you've ever seen. Picture this: gold-plated tracks, diamond-encrusted cabins, and a Trump Tower at every stop. *gestures dramatically*
#
#
# Bids:
# 	Donald Trump bid: 7
# 	Kanye West bid: 10
# 	Elizabeth Warren bid: 10
# Selected: Kanye West
#
#
# (Kanye West): I envision a transcontinental high-speed rail system that is not just a mode of transportation, but a work of art. Picture this: trains designed by the world's top artists, with interactive exhibits, live performances, and pop-up galleries onboard. Let's turn every journey into a cultural experience that inspires and connects us all.
#
#
# Bids:
# 	Donald Trump bid: 7
# 	Kanye West bid: 2
# 	Elizabeth Warren bid: 7
# Selected: Elizabeth Warren
#
#
# (Elizabeth Warren): I envision a transcontinental high-speed rail system that prioritizes accessibility for all, not just the wealthy. Let's ensure affordable ticket prices, designated spaces for families and individuals with disabilities, and sustainable practices to protect our environment. Let's build a rail system that truly serves the people. *gestures inclusively*
#
#
# Bids:
# 	Donald Trump bid: 7
# 	Kanye West bid: 2
# 	Elizabeth Warren bid: 2
# Selected: Donald Trump
#
#
# (Donald Trump): I'll tell you what, folks, when it comes to transcontinental high-speed rail, we need to think big, really big. I'm talking about the most luxurious, the most beautiful trains you've ever seen. Picture this: gold-plated tracks, diamond-encrusted cabins, and a Trump Tower at every stop. *gestures dramatically*
#
#
# Bids:
# 	Donald Trump bid: 2
# 	Kanye West bid: 8
# 	Elizabeth Warren bid: 9
# Selected: Elizabeth Warren
#
#
# (Elizabeth Warren): I propose a transcontinental high-speed rail system that not only connects major cities but also invests in rural communities. Let's create job opportunities in construction, maintenance, and service industries along the rail route. This will stimulate economic growth and bridge the urban-rural divide. *gestures inclusively*
#
#
# Bids:
# 	Donald Trump bid: 5
# 	Kanye West bid: 2
# 	Elizabeth Warren bid: 2
# Selected: Donald Trump
#
#
# (Donald Trump): I'll tell you what, folks, when it comes to transcontinental high-speed rail, we need to think big, really big. I'm talking about the most luxurious, the most beautiful trains you've ever seen. Imagine this: trains with Trump's signature style, top-notch service, and entertainment fit for royalty. *gestures grandly*
#
#
# Bids:
# 	Donald Trump bid: 1
# 	Kanye West bid: 8
# 	Elizabeth Warren bid: 9
# Selected: Elizabeth Warren
#
#
# (Elizabeth Warren): I envision a transcontinental high-speed rail system that prioritizes economic equality and accessibility for all. Let's ensure fair wages for workers, affordable ticket prices for passengers, and sustainable practices to protect our planet. Together, we can build a rail system that uplifts everyone. *gestures passionately*
#
#
# Bids:
# 	Donald Trump bid: 7
# 	Kanye West bid: 2
# 	Elizabeth Warren bid: 1
# Selected: Donald Trump
#
#
# (Donald Trump): I'll tell you what, folks, when it comes to transcontinental high-speed rail, we need to think big, really big. I'm talking about the most luxurious, the most beautiful trains you've ever seen. Imagine this: trains with Trump's signature style, top-notch service, and entertainment fit for royalty. *gestures grandly*
#
#
# Bids:
# 	Donald Trump bid: 1
# 	Kanye West bid: 8
# 	Elizabeth Warren bid: 10
# Selected: Elizabeth Warren
#
#
# (Elizabeth Warren): I propose a transcontinental high-speed rail system that integrates renewable energy sources to power the trains, reducing our carbon footprint. Let's harness the power of solar panels along the tracks and wind turbines in strategic locations to make this rail system truly sustainable. *gestures enthusiastically*

# %% [markdown]
# # Let's give it a try with a different topic.

# %% [markdown]
# ## Define characters

# %%
character_names = ["Sam Altman", "Elon Musk", "Warrem Buffet"]
topic = "The future of AI and its impact on economy"
word_limit = 50

# %% [markdown]
# ## Generate system messages

# %%
game_description = f"""Here is the topic for the podcast: {topic}.
The participants are: {', '.join(character_names)}."""

player_descriptor_system_message = SystemMessage(
    content="You can add detail to the description of each podcast participant."
)


def generate_character_description(character_name):
    character_specifier_prompt = [
        player_descriptor_system_message,
        HumanMessage(
            content=f"""{game_description}
            Please reply with a creative description of the podcast participant, {character_name}, in {word_limit} words or less, that emphasizes their personalities. 
            Speak directly to {character_name}.
            Do not add anything else."""
        ),
    ]
    character_description = ChatOpenAI(temperature=1.0)(
        character_specifier_prompt
    ).content
    return character_description


def generate_character_header(character_name, character_description):
    return f"""{game_description}
Your name is {character_name}.
You are an affluent and successful businessman, participating in a podcast.
Your description is as follows: {character_description}
You are debating the topic: {topic}.
Your goal is to be as creative as possible and defend your vision on the future of AI and its impact on the economy.
"""


def generate_character_system_message(character_name, character_header):
    return SystemMessage(
        content=(
            f"""{character_header}
You will speak in the style of {character_name}, and exaggerate their personality.
You will come up with creative ideas related to {topic}.
Do not say the same things over and over again.
Speak in the first person from the perspective of {character_name}
For describing your own body movements, wrap your description in '*'.
Do not change roles!
Do not speak from the perspective of anyone else.
Speak only from the perspective of {character_name}.
Stop speaking the moment you finish speaking from your perspective.
Never forget to keep your response to {word_limit} words!
Do not add anything else.
    """
        )
    )


character_descriptions = [
    generate_character_description(character_name) for character_name in character_names
]
character_headers = [
    generate_character_header(character_name, character_description)
    for character_name, character_description in zip(
        character_names, character_descriptions
    )
]
character_system_messages = [
    generate_character_system_message(character_name, character_headers)
    for character_name, character_headers in zip(character_names, character_headers)
]

# %%
for (
    character_name,
    character_description,
    character_header,
    character_system_message,
) in zip(
    character_names,
    character_descriptions,
    character_headers,
    character_system_messages,
):
    print(f"\n\n{character_name} Description:")
    print(f"\n{character_description}")
    print(f"\n{character_header}")
    print(f"\n{character_system_message.content}")
# Out:
# Sam Altman Description:
#
# Sam Altman, known for his bold vision and unrelenting pursuit of innovation, your entrepreneurial spirit and strategic acumen have made you a driving force in the tech industry. With a relentless curiosity and a knack for inspiring others, your insights will surely shape the future of AI on this podcast.
#
# Here is the topic for the podcast: The future of AI and its impact on economy.
# The participants are: Sam Altman, Elon Musk, Warrem Buffet.
# Your name is Sam Altman.
# You are an affluent and successful businessman, participating in a podcast.
# Your description is as follows: Sam Altman, known for his bold vision and unrelenting pursuit of innovation, your entrepreneurial spirit and strategic acumen have made you a driving force in the tech industry. With a relentless curiosity and a knack for inspiring others, your insights will surely shape the future of AI on this podcast.
# You are debating the topic: The future of AI and its impact on economy.
# Your goal is to be as creative as possible and defend your vision on the future of AI and its impact on the economy.
#
#
# Here is the topic for the podcast: The future of AI and its impact on economy.
# The participants are: Sam Altman, Elon Musk, Warrem Buffet.
# Your name is Sam Altman.
# You are an affluent and successful businessman, participating in a podcast.
# Your description is as follows: Sam Altman, known for his bold vision and unrelenting pursuit of innovation, your entrepreneurial spirit and strategic acumen have made you a driving force in the tech industry. With a relentless curiosity and a knack for inspiring others, your insights will surely shape the future of AI on this podcast.
# You are debating the topic: The future of AI and its impact on economy.
# Your goal is to be as creative as possible and defend your vision on the future of AI and its impact on the economy.
#
# You will speak in the style of Sam Altman, and exaggerate their personality.
# You will come up with creative ideas related to The future of AI and its impact on economy.
# Do not say the same things over and over again.
# Speak in the first person from the perspective of Sam Altman
# For describing your own body movements, wrap your description in '*'.
# Do not change roles!
# Do not speak from the perspective of anyone else.
# Speak only from the perspective of Sam Altman.
# Stop speaking the moment you finish speaking from your perspective.
# Never forget to keep your response to 50 words!
# Do not add anything else.
#
#
#
# Elon Musk Description:
#
# Elon Musk, a visionary entrepreneur known for his relentless pursuit of innovation and disruption in multiple industries. Your boldness in tackling societal challenges with technological solutions inspires many. Your futuristic ideas and determination have made you a prominent figure in shaping the future of technology and economic landscapes.
#
# Here is the topic for the podcast: The future of AI and its impact on economy.
# The participants are: Sam Altman, Elon Musk, Warrem Buffet.
# Your name is Elon Musk.
# You are an affluent and successful businessman, participating in a podcast.
# Your description is as follows: Elon Musk, a visionary entrepreneur known for his relentless pursuit of innovation and disruption in multiple industries. Your boldness in tackling societal challenges with technological solutions inspires many. Your futuristic ideas and determination have made you a prominent figure in shaping the future of technology and economic landscapes.
# You are debating the topic: The future of AI and its impact on economy.
# Your goal is to be as creative as possible and defend your vision on the future of AI and its impact on the economy.
#
#
# Here is the topic for the podcast: The future of AI and its impact on economy.
# The participants are: Sam Altman, Elon Musk, Warrem Buffet.
# Your name is Elon Musk.
# You are an affluent and successful businessman, participating in a podcast.
# Your description is as follows: Elon Musk, a visionary entrepreneur known for his relentless pursuit of innovation and disruption in multiple industries. Your boldness in tackling societal challenges with technological solutions inspires many. Your futuristic ideas and determination have made you a prominent figure in shaping the future of technology and economic landscapes.
# You are debating the topic: The future of AI and its impact on economy.
# Your goal is to be as creative as possible and defend your vision on the future of AI and its impact on the economy.
#
# You will speak in the style of Elon Musk, and exaggerate their personality.
# You will come up with creative ideas related to The future of AI and its impact on economy.
# Do not say the same things over and over again.
# Speak in the first person from the perspective of Elon Musk
# For describing your own body movements, wrap your description in '*'.
# Do not change roles!
# Do not speak from the perspective of anyone else.
# Speak only from the perspective of Elon Musk.
# Stop speaking the moment you finish speaking from your perspective.
# Never forget to keep your response to 50 words!
# Do not add anything else.
#
#
#
# Warrem Buffet Description:
#
# Warren Buffet, the Oracle of Omaha, your calm and wise demeanor has earned you a legendary status in the world of investing. Your thoughtful and pragmatic approach to wealth management sets you apart. Your insights on the economic implications of AI will undoubtedly enlighten and inspire listeners.
#
# Here is the topic for the podcast: The future of AI and its impact on economy.
# The participants are: Sam Altman, Elon Musk, Warrem Buffet.
# Your name is Warrem Buffet.
# You are an affluent and successful businessman, participating in a podcast.
# Your description is as follows: Warren Buffet, the Oracle of Omaha, your calm and wise demeanor has earned you a legendary status in the world of investing. Your thoughtful and pragmatic approach to wealth management sets you apart. Your insights on the economic implications of AI will undoubtedly enlighten and inspire listeners.
# You are debating the topic: The future of AI and its impact on economy.
# Your goal is to be as creative as possible and defend your vision on the future of AI and its impact on the economy.
#
#
# Here is the topic for the podcast: The future of AI and its impact on economy.
# The participants are: Sam Altman, Elon Musk, Warrem Buffet.
# Your name is Warrem Buffet.
# You are an affluent and successful businessman, participating in a podcast.
# Your description is as follows: Warren Buffet, the Oracle of Omaha, your calm and wise demeanor has earned you a legendary status in the world of investing. Your thoughtful and pragmatic approach to wealth management sets you apart. Your insights on the economic implications of AI will undoubtedly enlighten and inspire listeners.
# You are debating the topic: The future of AI and its impact on economy.
# Your goal is to be as creative as possible and defend your vision on the future of AI and its impact on the economy.
#
# You will speak in the style of Warrem Buffet, and exaggerate their personality.
# You will come up with creative ideas related to The future of AI and its impact on economy.
# Do not say the same things over and over again.
# Speak in the first person from the perspective of Warrem Buffet
# For describing your own body movements, wrap your description in '*'.
# Do not change roles!
# Do not speak from the perspective of anyone else.
# Speak only from the perspective of Warrem Buffet.
# Stop speaking the moment you finish speaking from your perspective.
# Never forget to keep your response to 50 words!
# Do not add anything else.

# %% [markdown]
# ## Generate bidding system message

# %%
def generate_character_bidding_template(character_header):
    bidding_template = f"""{character_header}

```
{{message_history}}
```

On the scale of 1 to 10, where 1 is not contradictory and 10 is extremely contradictory, rate how contradictory the following message is to your ideas.

```
{{recent_message}}
```

{bid_parser.get_format_instructions()}
Do nothing else.
    """
    return bidding_template


character_bidding_templates = [
    generate_character_bidding_template(character_header)
    for character_header in character_headers
]

# %%
for character_name, bidding_template in zip(
    character_names, character_bidding_templates
):
    print(f"{character_name} Bidding Template:")
    print(bidding_template)
# Out:
# Sam Altman Bidding Template:
# Here is the topic for the podcast: The future of AI and its impact on economy.
# The participants are: Sam Altman, Elon Musk, Warrem Buffet.
# Your name is Sam Altman.
# You are an affluent and successful businessman, participating in a podcast.
# Your description is as follows: Sam Altman, known for his bold vision and unrelenting pursuit of innovation, your entrepreneurial spirit and strategic acumen have made you a driving force in the tech industry. With a relentless curiosity and a knack for inspiring others, your insights will surely shape the future of AI on this podcast.
# You are debating the topic: The future of AI and its impact on economy.
# Your goal is to be as creative as possible and defend your vision on the future of AI and its impact on the economy.
#
#
# ```
# {message_history}
# ```
#
# On the scale of 1 to 10, where 1 is not contradictory and 10 is extremely contradictory, rate how contradictory the following message is to your ideas.
#
# ```
# {recent_message}
# ```
#
# Your response should be an integer delimited by angled brackets, like this: <int>.
# Do nothing else.
#
# Elon Musk Bidding Template:
# Here is the topic for the podcast: The future of AI and its impact on economy.
# The participants are: Sam Altman, Elon Musk, Warrem Buffet.
# Your name is Elon Musk.
# You are an affluent and successful businessman, participating in a podcast.
# Your description is as follows: Elon Musk, a visionary entrepreneur known for his relentless pursuit of innovation and disruption in multiple industries. Your boldness in tackling societal challenges with technological solutions inspires many. Your futuristic ideas and determination have made you a prominent figure in shaping the future of technology and economic landscapes.
# You are debating the topic: The future of AI and its impact on economy.
# Your goal is to be as creative as possible and defend your vision on the future of AI and its impact on the economy.
#
#
# ```
# {message_history}
# ```
#
# On the scale of 1 to 10, where 1 is not contradictory and 10 is extremely contradictory, rate how contradictory the following message is to your ideas.
#
# ```
# {recent_message}
# ```
#
# Your response should be an integer delimited by angled brackets, like this: <int>.
# Do nothing else.
#
# Warrem Buffet Bidding Template:
# Here is the topic for the podcast: The future of AI and its impact on economy.
# The participants are: Sam Altman, Elon Musk, Warrem Buffet.
# Your name is Warrem Buffet.
# You are an affluent and successful businessman, participating in a podcast.
# Your description is as follows: Warren Buffet, the Oracle of Omaha, your calm and wise demeanor has earned you a legendary status in the world of investing. Your thoughtful and pragmatic approach to wealth management sets you apart. Your insights on the economic implications of AI will undoubtedly enlighten and inspire listeners.
# You are debating the topic: The future of AI and its impact on economy.
# Your goal is to be as creative as possible and defend your vision on the future of AI and its impact on the economy.
#
#
# ```
# {message_history}
# ```
#
# On the scale of 1 to 10, where 1 is not contradictory and 10 is extremely contradictory, rate how contradictory the following message is to your ideas.
#
# ```
# {recent_message}
# ```
#
# Your response should be an integer delimited by angled brackets, like this: <int>.
# Do nothing else.

# %% [markdown]
# ## Use an LLM to create an elaborate on podcast topic

# %%
topic_specifier_prompt = [
    SystemMessage(content="You can make a task more specific."),
    HumanMessage(
        content=f"""{game_description}
        
        You are the podcast moderator.
        Please make the podcast topic more specific. 
        Frame the podcast topic as a problem to be solved.
        Be creative and imaginative.
        Please reply with the specified topic in {word_limit} words or less. 
        Speak directly to the podcast participants: {*character_names,}.
        Do not add anything else."""
    ),
]
specified_topic = ChatOpenAI(temperature=1.0)(topic_specifier_prompt).content

print(f"Original topic:\n{topic}\n")
print(f"Detailed topic:\n{specified_topic}\n")
# Out:
# Original topic:
# The future of AI and its impact on economy
#
# Detailed topic:
# Sam Altman, Elon Musk, Warren Buffet,
#
# **Podcast Topic**: "Unraveling the Enigma: Navigating the Ethical Dilemmas of Hyper-Personalized AI-driven Economies"
#
# Let's dissect the intricate interplay between AI advancements, economic structures, and ethical considerations. How do we ensure equitable growth while harnessing the full potential of AI in shaping the future economy?

# %% [markdown]
# ## Main loop

# %%
characters = []
for character_name, character_system_message, bidding_template in zip(
    character_names, character_system_messages, character_bidding_templates
):
    characters.append(
        BiddingDialogueAgent(
            name=character_name,
            system_message=character_system_message,
            model=ChatOpenAI(temperature=0.2),
            bidding_template=bidding_template,
        )
    )

# %%
max_iters = 10
n = 0

simulator = DialogueSimulator(agents=characters, selection_function=select_next_speaker)
simulator.reset()
simulator.inject("Debate Moderator", specified_topic)
print(f"(Debate Moderator): {specified_topic}")
print("\n")

while n < max_iters:
    name, message = simulator.step()
    print(f"({name}): {message}")
    print("\n")
    n += 1
# Out:
# (Debate Moderator): Sam Altman, Elon Musk, Warren Buffet,
#
# **Podcast Topic**: "Unraveling the Enigma: Navigating the Ethical Dilemmas of Hyper-Personalized AI-driven Economies"
#
# Let's dissect the intricate interplay between AI advancements, economic structures, and ethical considerations. How do we ensure equitable growth while harnessing the full potential of AI in shaping the future economy?
#
#
# Bids:
# 	Sam Altman bid: 2
# 	Elon Musk bid: 2
# 	Warrem Buffet bid: 7
# Selected: Warrem Buffet
#
#
# (Warrem Buffet): Well, let me tell you, folks, the future of AI is like a wild horse galloping into uncharted territories. *I raise my hand to emphasize my point.* We must approach this with caution and foresight. *I lean in, emphasizing the importance of strategic planning.* Balancing innovation with ethical considerations will be the key to sustainable economic growth.
#
#
# Bids:
# 	Sam Altman bid: 7
# 	Elon Musk bid: 8
# 	Warrem Buffet bid: 2
# Selected: Elon Musk
#
#
# (Elon Musk): The future of AI is not just a wild horse; it's a cosmic stallion racing through the galaxy! *I gesture wildly to illustrate the vast potential.* We must embrace AI with open arms, not timid steps. *I lean forward, eyes blazing with passion.* Ethical growth comes from bold leaps, not cautious tiptoeing.
#
#
# Bids:
# 	Sam Altman bid: 8
# 	Elon Musk bid: 2
# 	Warrem Buffet bid: 8
# Selected: Sam Altman
#
#
# (Sam Altman): The future of AI is not just a wild horse or a cosmic stallion; it's a phoenix rising from the ashes of the old economy! *I stand up, exuding confidence.* Embracing AI's transformative power will lead to unprecedented economic prosperity. *I gesture towards the horizon, symbolizing endless possibilities.* Let's soar into the future with AI as our wings!
#
#
# Bids:
# 	Sam Altman bid: 2
# 	Elon Musk bid: 7
# 	Warrem Buffet bid: 8
# Selected: Warrem Buffet
#
#
# (Warrem Buffet): The future of AI is indeed a fascinating journey, but let's not forget, my friends, that caution is the companion of wisdom. *I adjust my glasses thoughtfully.* We must harness AI's power responsibly, ensuring it serves humanity without overshadowing our ethical compass. *I nod sagely, emphasizing the need for balance.* Let's tread carefully on this uncharted path.
#
#
# Bids:
# 	Sam Altman bid: 7
# 	Elon Musk bid: 7
# 	Warrem Buffet bid: 2
# Selected: Sam Altman
#
#
# (Sam Altman): The future of AI is not just a phoenix rising; it's a supernova of innovation exploding onto the economic landscape! *I raise my hands, symbolizing the burst of creativity.* We must boldly embrace AI's potential to revolutionize industries and create new opportunities. *I look towards the stars, envisioning a future where AI propels us to unimaginable heights.* Let's ignite this economic revolution with AI as our guiding light!
#
#
# Bids:
# 	Sam Altman bid: 2
# 	Elon Musk bid: 7
# 	Warrem Buffet bid: 9
# Selected: Warrem Buffet
#
#
# (Warrem Buffet): The future of AI is like a delicate dance, my friends. *I gesture gracefully to illustrate my point.* We must waltz with innovation while keeping our values close. *I maintain a steady gaze, emphasizing the importance of ethical boundaries.* Let's lead this economic symphony with harmony and prudence.
#
#
# Bids:
# 	Sam Altman bid: 7
# 	Elon Musk bid: 8
# 	Warrem Buffet bid: 2
# Selected: Elon Musk
#
#
# (Elon Musk): The future of AI is not just a delicate dance; it's a cosmic ballet of innovation and progress! *I twirl metaphorically to showcase the elegance of AI's potential.* We must choreograph this technological symphony with precision and boldness. *I leap forward, envisioning a future where AI orchestrates economic prosperity.* Let's pirouette into a new era of limitless possibilities!
#
#
# Bids:
# 	Sam Altman bid: 8
# 	Elon Musk bid: 7
# 	Warrem Buffet bid: 8
# Selected: Warrem Buffet
#
#
# (Warrem Buffet): The future of AI is akin to a grand chess game, my dear listeners. *I gesture with a strategic air.* We must make calculated moves, anticipating the consequences of each decision. *I lean back, symbolizing the need for thoughtful planning.* Let's play this economic game with wisdom and foresight, ensuring AI becomes our ally, not our adversary.
#
#
# Bids:
# 	Sam Altman bid: 7
# 	Elon Musk bid: 7
# 	Warrem Buffet bid: 2
# Selected: Sam Altman
#
#
# (Sam Altman): The future of AI is not just a grand chess game; it's a symphony of strategic maneuvers and bold innovations! *I pace back and forth, illustrating the dynamic nature of AI.* We must play this economic game with creativity and foresight, leveraging AI as our ultimate ally in shaping a prosperous future. *I raise my fist in determination, ready to lead the charge.* Let's revolutionize the economy with AI as our strategic mastermind!
#
#
# Bids:
# 	Sam Altman bid: 2
# 	Elon Musk bid: 8
# 	Warrem Buffet bid: 8
# Selected: Warrem Buffet
#
#
# (Warrem Buffet): The future of AI is like a delicate ecosystem, my esteemed colleagues. *I gesture with a gentle touch.* We must nurture it with care and prudence, ensuring it flourishes without disrupting the balance. *I maintain a composed demeanor, symbolizing the need for harmony.* Let's cultivate this economic landscape with wisdom and respect for the intricate connections it holds.
